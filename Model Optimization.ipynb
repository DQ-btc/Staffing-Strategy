# %%
# mounting
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/MyDrive/Google Comp')

# %%
# import the data from /[BADSS case] Agent Salary and Eligibility Threshold - data.csv and /[BADSS case] Existing Agent Staffing - data.csv
import pandas as pd
df1 = pd.read_csv('/content/drive/MyDrive/Google Comp/[BADSS case] Agent Salary and Eligibility Threshold - data.csv')
df2 = pd.read_csv('/content/drive/MyDrive/Google Comp/[BADSS case] Existing Agent Staffing - data.csv')
